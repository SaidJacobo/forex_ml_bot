# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, auc, roc_curve
import itertools
import yaml
import os
import numpy as np
from sklearn.metrics import auc
from statistics import mean
import re

# %%
def calculate_auc_avg(tickers, predictions, true_values):
    predictions = predictions.sort_values(by='fecha')
    true_values = true_values.sort_values(by='fecha')
    
    
    # renombro las columnas
    column_names = {}
    for column in predictions.columns:
        if column != 'fecha':
            column_names[column] = f'{column}_proba'
    
    predictions = predictions.rename(columns=column_names)
    
    column_names = {}
    for column in true_values.columns:
        if column != 'fecha':
            column_names[column] = f'{column}_true'
    
    true_values = true_values.rename(columns=column_names)
    performance = pd.concat(
        [
            predictions,
            true_values
        ], axis=1, join="inner"
    )
    
    auc_list = []
    for ticker in tickers:
        y_true = performance[performance[f'{ticker}_true'].notna()][f'{ticker}_true']
        y_pred = performance[performance[f'{ticker}_proba'].notna()][f'{ticker}_proba']
        
        fpr, tpr, thresholds = roc_curve(y_true, y_pred)
        auc_score = auc(fpr, tpr)
        
        auc_list.append(auc_score)

    return mean(auc_list)

# %%
with open('configs/project_config.yml', 'r') as archivo:
    config = yaml.safe_load(archivo)

tickers = config["tickers"] 
tickers
# Out:
# ['YPF', 'BBAR', 'BMA', 'CEPU', 'EDN', 'TEO', 'LOMA']

# %%
results_dict = {}

for path in os.listdir('./data'):
    if not path.endswith('.csv') and path.startswith('mode_train'):
        print(path)
        results_dict[path] = {}

        try:
            wallet = pd.read_csv(os.path.join('./data', path, 'wallet.csv'))
            results_dict[path]['wallet'] = wallet.tail(1).iloc[0]['wallet']
        except:
            results_dict[path]['wallet'] = 0

        try:
            orders = pd.read_csv(os.path.join('./data', path, 'orders.csv'))
            results_dict[path]['buys'] = orders[orders['open_date'].notna()].shape[0]
            results_dict[path]['sells'] = orders[orders['close_date'].notna()].shape[0]
           
            avg_incomes = orders.groupby('ticker')['profit'].sum().mean()
            results_dict[path]['avg_incomes'] = avg_incomes
            results_dict[path]['good_operations'] = orders[orders['profit'] > 0].shape[0]
            results_dict[path]['bad_operations'] = orders[orders['profit'] <= 0].shape[0]
            results_dict[path]['operation_ratio'] = results_dict[path]['good_operations'] / (results_dict[path]['good_operations'] + results_dict[path]['bad_operations']) 

        except:
            results_dict[path]['buys'] = 0
            results_dict[path]['sells'] = 0
            avg_incomes = 0
            results_dict[path]['avg_incomes'] = 0
            results_dict[path]['good_operations'] = 0
            results_dict[path]['bad_operations'] = 0
            results_dict[path]['operation_ratio'] = 0

        try:
            train_results = pd.read_csv(os.path.join('./data', path, 'train_results.csv'))
            avg_train_auc = train_results['auc'].mean()
            results_dict[path]['avg_train_auc'] = avg_train_auc
        except:
            results_dict[path]['avg_train_auc'] = 0
            
        try:
            stock_predictions = pd.read_csv(os.path.join('./data', path, 'stock_predictions.csv'))
            true_values = pd.read_csv(os.path.join('./data', path, 'stock_true_values.csv'))

            avg_auc_score = calculate_auc_avg(tickers, stock_predictions, true_values)
            results_dict[path]['avg_test_auc'] = avg_auc_score
        except:
            results_dict[path]['avg_test_auc'] = 0

results = pd.DataFrame.from_dict(results_dict, orient='index')
# Out:
# mode_train-model_gradient_boosting-trainwindow_114-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_gradient_boosting-trainwindow
trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_neural_network-trainwindow_76-trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_None-trainwindow_0-trainperiod_0-tradingstrategy_strategies.bband_strategy
# mode_train-model_None-trainwindow_0-trainperiod_0-tradingstrategy_strategies.macd_strategy
# mode_train-model_None-trainwindow_0-trainperiod_0-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_114-trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_228-trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_38-trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_461-trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_689-trainperiod_7-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_1-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_1-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_1-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_1-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_14-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_14-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_14-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_14-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_30-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_30-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_30-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_30-tradingstrategy_strategies.ml_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_7-tradingstrategy_strategies.bband_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_7-tradingstrategy_strategies.macd_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_7-tradingstrategy_strategies.ma_strategy
# mode_train-model_random_forest-trainwindow_76-trainperiod_7-tradingstrategy_strategies.ml_strategy

# %%
beta = 0.1

results['buy_ratio'] = results['buys'] / results['buys'].max()
results['operation_ratio_2'] = ((1 + beta**2) * results['operation_ratio'] * results['buy_ratio']) / (beta * results['operation_ratio'] + results['buy_ratio'])

results = results.sort_values(by=['operation_ratio_2'], ascending=[False])[
    [
        'operation_ratio_2',
        'operation_ratio', 
        'buy_ratio',
        'good_operations',
        'bad_operations',
        'avg_train_auc',
        'avg_test_auc',
        'wallet',
    ]
]

# %%
results = results.reset_index().rename(columns={'index':'config'})

# %% [markdown]
# # With / without model

# %%
results['window'] = results['config'].apply(lambda x: re.search(r"trainwindow_(.*?)-", x).group(1))
results['with_model'] = np.where(results['window']!='0', 1, 0)

pd.DataFrame(
    results.groupby('with_model')['operation_ratio_2'].mean()
).sort_values(by='operation_ratio_2', ascending=False)
# Out:
#             operation_ratio_2
# with_model
# 0                    0.467023
# 1                    0.204250

# %%
results[results['with_model']==0]
# Out:
#                                                config  operation_ratio_2  \
# 3   mode_train-model_None-trainwindow_0-trainperio...           0.631550
# 46  mode_train-model_None-trainwindow_0-trainperio...           0.391626
# 53  mode_train-model_None-trainwindow_0-trainperio...           0.377891
#
#     operation_ratio  buy_ratio  good_operations  bad_operations  \
# 3          0.667005   1.000000              657             328
# 46         0.428571   0.407071              171             228
# 53         0.515625   0.136364               66              62
#
#     avg_train_auc  avg_test_auc      wallet window  with_model
# 3             0.0           0.0   95.694334      0           0
# 46            0.0           0.0  130.672527      0           0
# 53            0.0           0.0  118.399752      0           0

# %%
results[results['with_model']==1].head(3)
# Out:
#                                               config  operation_ratio_2  \
# 0  mode_train-model_gradient_boosting-trainwindow...           0.703360
# 1  mode_train-model_gradient_boosting-trainwindow...           0.665776
# 2  mode_train-model_gradient_boosting-trainwindow...           0.645991
#
#    operation_ratio  buy_ratio  good_operations  bad_operations  avg_train_auc  \
# 0         0.859116   0.367677              311              51        0.99583
# 1         0.826087   0.326263              266              56        0.99625
# 2         0.860082   0.249495              209              34        0.99981
#
#    avg_test_auc      wallet window  with_model
# 0      0.757644  164.526840     38           1
# 1      0.601851  143.678815     38           1
# 2      0.743258  148.151279    461           1

# %% [markdown]
# # Window

# %%
results = results[results['with_model'] == 1]
pd.DataFrame(
    results.groupby('window')['operation_ratio_2'].mean()
).sort_values(by='operation_ratio_2', ascending=False)
# Out:
#         operation_ratio_2
# window
# 38               0.263682
# 114              0.255792
# 76               0.201770
# 461              0.170956
# 228              0.164837
# 689              0.163348

# %% [markdown]
# # trainperiod

# %%
results['trainperiod'] = results['config'].apply(lambda x: re.search(r'trainperiod_(.*?)-', x).group(1))
pd.DataFrame(
    results.groupby('trainperiod')['operation_ratio_2'].mean()
).sort_values(by='operation_ratio_2', ascending=False)
# Out:
#              operation_ratio_2
# trainperiod
# 1                     0.220786
# 7                     0.205062
# 14                    0.201694
# 30                    0.189456

# %% [markdown]
# # Model

# %%
results['model'] = results['config'].apply(lambda x: re.search(r'model_(.*?)-', x).group(1))
pd.DataFrame(
    results.groupby('model')['operation_ratio_2'].mean()
).sort_values(by='operation_ratio_2', ascending=False)
# Out:
#                      operation_ratio_2
# model
# gradient_boosting             0.252730
# random_forest                 0.218578
# neural_network                0.193541
# logistic_regression           0.147414

# %% [markdown]
# # Strategy

# %%
results['tradingstrategy'] = results['config'].apply(lambda x: re.search(r'tradingstrategy_(.*)', x).group(1))
pd.DataFrame(
    results.groupby('tradingstrategy')['operation_ratio_2'].mean()
).sort_values(by='operation_ratio_2', ascending=False)
# Out:
#                            operation_ratio_2
# tradingstrategy
# strategies.bband_strategy           0.349199
# strategies.macd_strategy            0.201416
# strategies.ma_strategy              0.162157
# strategies.ml_strategy              0.108512
