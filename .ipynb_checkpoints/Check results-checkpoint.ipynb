# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, auc, roc_curve
import itertools
import yaml
import os
import numpy as np
from statistics import mean
from IPython.display import clear_output
from datetime import datetime, timedelta
import time
from sklearn.metrics import precision_recall_curve, auc
pd.options.display.max_rows = 999
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title='Matriz de Confusión',
                          cmap=plt.cm.Blues):
    """
    Esta función imprime y plotea la matriz de confusión.
    La normalización se puede aplicar configurando `normalize=True`.
    """
    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(6, 4))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Etiqueta Verdadera')
    plt.xlabel('Etiqueta Predicha')
    plt.tight_layout()

# %%
with open('configs/project_config.yml', 'r') as archivo:
    config = yaml.safe_load(archivo)

initial_wallet_value = config['start_money']

# %%
root_path = './backbone/data/backtest/experiments'
# root_path = 'C:/Users/SaidJ/OneDrive/Documentos/projects/forex_ml_bot/experiments 20240623'


path = 'Mode_train-Model_random_forest-TrainWw_11520-TrainPd_24-TradStgy_ml_strategy-PerFwTg_8-SL_15-RR_2-CloseByTimeTrue-TS_False'
orders = pd.read_csv(os.path.join(root_path, path, 'orders.csv'))
wallet = pd.read_csv(os.path.join(root_path, path, 'wallet.csv'))

# %%
orders
# Out:
#                                        id  ticker      operation_type  \
# 0    2eb02c9c-374d-11ef-9a6a-958c92a01fe8  USDCAD   OperationType.BUY
# 1    31aaa9b4-374d-11ef-9b37-958c92a01fe8  GBPUSD   OperationType.BUY
# 2    31d0b1e9-374d-11ef-8837-958c92a01fe8  USDCAD  OperationType.SELL
# 3    31d6b647-374d-11ef-9d31-958c92a01fe8  AUDUSD   OperationType.BUY
# 4    31ef410a-374d-11ef-887f-958c92a01fe8  USDCHF  OperationType.SELL
# 5    3246f536-374d-11ef-9bd8-958c92a01fe8  EURUSD   OperationType.BUY
# 6    354e668c-374d-11ef-9535-958c92a01fe8  AUDUSD  OperationType.SELL
# 7    358cce14-374d-11ef-acae-958c92a01fe8  GBPUSD  OperationType.SELL
# 8    35ca1fb2-374d-11ef-85fa-958c92a01fe8  EURUSD  OperationType.SELL
# 9    3882af7d-374d-11ef-b090-958c92a01fe8  USDCAD  OperationType.SELL
# 10   38c34b6a-374d-11ef-b5d9-958c92a01fe8  GBPUSD   OperationType.BUY
# 11   391de4a5-374d-11ef-a928-958c92a01fe8  EURUSD   OperationType.BUY
# 12   39364674-374d-11ef-8f8c-958c92a01fe8  USDJPY  OperationType.SELL
# 13   39664a82-374d-11ef-8009-958c92a01fe8  AUDUSD   OperationType.BUY
# 14   39843c78-374d-11ef-952d-958c92a01fe8  USDCHF  OperationType.SELL
# 15   3ccc1519-374d-11ef-a5d7-958c92a01fe8  USDCHF   OperationType.BUY
# 16   3d0d80b7-374d-11ef-9335-958c92a01fe8  GBPUSD  OperationType.SELL
# 17   3d818e53-374d-11ef-9a19-958c92a01fe8  GBPUSD   OperationType.BUY
# 18   3fe55819-374d-11ef-baec-958c92a01fe8  USDCAD  OperationType.SELL
# 19   3ffb0bcc-374d-11ef-8304-958c92a01fe8  AUDUSD   OperationType.BUY
# 20   404a2014-374d-11ef-ad94-958c92a01fe8  USDCHF  OperationType.SELL
# 127  2022-04-07 07:00:00  2022-04-07 09:00:00      1.0914      1.0914
# 128  2022-04-07 12:00:00  2022-04-07 20:00:00    123.7200    123.7200
# 129  2022-04-08 16:00:00  2022-04-08 18:00:00      1.2612      1.2612
# 130  2022-04-11 02:00:00  2022-04-11 05:00:00      1.2581      1.2581
# 131  2022-04-12 00:00:00  2022-04-12 08:00:00      1.3028      1.3028
# 132  2022-04-12 07:00:00  2022-04-12 15:00:00      0.7427      0.7427
# 133  2022-04-12 09:00:00  2022-04-12 15:00:00    125.7000    125.7000
# 134  2022-04-13 05:00:00  2022-04-13 09:00:00      0.7471      0.7471
# ...
# 88   ClosePositionType.TAKE_PROFIT
# 89          ClosePositionType.DAYS
# 90          ClosePositionType.DAYS
# 91     ClosePositionType.STOP_LOSS
# 92   ClosePositionType.TAKE_PROFIT
# 93   ClosePositionType.TAKE_PROFIT
# 94   ClosePositionType.TAKE_PROFIT
# 95          ClosePositionType.DAYS
# 96   ClosePositionType.TAKE_PROFIT
# 97   ClosePositionType.TAKE_PROFIT
# 98   ClosePositionType.TAKE_PROFIT
# 99          ClosePositionType.DAYS
# 100    ClosePositionType.STOP_LOSS
# 101    ClosePositionType.STOP_LOSS
# 102  ClosePositionType.TAKE_PROFIT
# 103  ClosePositionType.TAKE_PROFIT
# 104  ClosePositionType.TAKE_PROFIT
# 105    ClosePositionType.STOP_LOSS
# 106  ClosePositionType.TAKE_PROFIT
# 107    ClosePositionType.STOP_LOSS
# 108    ClosePositionType.STOP_LOSS
# 109         ClosePositionType.DAYS
# 110    ClosePositionType.STOP_LOSS
# 111    ClosePositionType.STOP_LOSS
# 112         ClosePositionType.DAYS
# 113    ClosePositionType.STOP_LOSS
# 114  ClosePositionType.TAKE_PROFIT
# 115    ClosePositionType.STOP_LOSS
# 116  ClosePositionType.TAKE_PROFIT
# 117         ClosePositionType.DAYS
# 118  ClosePositionType.TAKE_PROFIT
# 119    ClosePositionType.STOP_LOSS
# 120  ClosePositionType.TAKE_PROFIT
# 121         ClosePositionType.DAYS
# 122         ClosePositionType.DAYS
# 123         ClosePositionType.DAYS
# 124    ClosePositionType.STOP_LOSS
# 125    ClosePositionType.STOP_LOSS
# 126    ClosePositionType.STOP_LOSS
# 127    ClosePositionType.STOP_LOSS
# 128         ClosePositionType.DAYS
# 129  ClosePositionType.TAKE_PROFIT
# 130  ClosePositionType.TAKE_PROFIT
# 131         ClosePositionType.DAYS
# 132         ClosePositionType.DAYS
# 133  ClosePositionType.TAKE_PROFIT
# 134  ClosePositionType.TAKE_PROFIT
# 135  ClosePositionType.TAKE_PROFIT
# 136    ClosePositionType.STOP_LOSS
# 137  ClosePositionType.TAKE_PROFIT
# 138  ClosePositionType.TAKE_PROFIT
# 139  ClosePositionType.TAKE_PROFIT
# 140         ClosePositionType.DAYS
# 141  ClosePositionType.TAKE_PROFIT
# 142  ClosePositionType.TAKE_PROFIT
# 143    ClosePositionType.STOP_LOSS
# 144    ClosePositionType.STOP_LOSS
# 145  ClosePositionType.TAKE_PROFIT
# 146  ClosePositionType.TAKE_PROFIT
# 147    ClosePositionType.STOP_LOSS
# 148  ClosePositionType.TAKE_PROFIT
# 149  ClosePositionType.TAKE_PROFIT
# 150    ClosePositionType.STOP_LOSS
# 151  ClosePositionType.TAKE_PROFIT
# 152         ClosePositionType.DAYS
# 153  ClosePositionType.TAKE_PROFIT
# 154  ClosePositionType.TAKE_PROFIT
# 155  ClosePositionType.TAKE_PROFIT
# 156    ClosePositionType.STOP_LOSS
# 157  ClosePositionType.TAKE_PROFIT
# 158  ClosePositionType.TAKE_PROFIT
# 159    ClosePositionType.STOP_LOSS
# 160         ClosePositionType.DAYS
# 161    ClosePositionType.STOP_LOSS
# 162    ClosePositionType.STOP_LOSS
# 163  ClosePositionType.TAKE_PROFIT
# 164  ClosePositionType.TAKE_PROFIT
# 165  ClosePositionType.TAKE_PROFIT
# 166  ClosePositionType.TAKE_PROFIT
# 167  ClosePositionType.TAKE_PROFIT
# 168         ClosePositionType.DAYS
# 169  ClosePositionType.TAKE_PROFIT
# 170  ClosePositionType.TAKE_PROFIT
# 171  ClosePositionType.TAKE_PROFIT
# 172  ClosePositionType.TAKE_PROFIT
# 173    ClosePositionType.STOP_LOSS
# 174  ClosePositionType.TAKE_PROFIT
# 175         ClosePositionType.DAYS
# 176  ClosePositionType.TAKE_PROFIT
# 177         ClosePositionType.DAYS
# 178    ClosePositionType.STOP_LOSS
# 179    ClosePositionType.STOP_LOSS
# 180  ClosePositionType.TAKE_PROFIT
# 181  ClosePositionType.TAKE_PROFIT
# 182    ClosePositionType.STOP_LOSS
# 183    ClosePositionType.STOP_LOSS
# 184    ClosePositionType.STOP_LOSS
# 185    ClosePositionType.STOP_LOSS
# 186    ClosePositionType.STOP_LOSS
# 187    ClosePositionType.STOP_LOSS
# 188  ClosePositionType.TAKE_PROFIT
# 189  ClosePositionType.TAKE_PROFIT
# 190  ClosePositionType.TAKE_PROFIT
# 191         ClosePositionType.DAYS
# 192         ClosePositionType.DAYS
# 193         ClosePositionType.DAYS
# 194    ClosePositionType.STOP_LOSS
# 195    ClosePositionType.STOP_LOSS
# 196  ClosePositionType.TAKE_PROFIT
# 197  ClosePositionType.TAKE_PROFIT
# 198  ClosePositionType.TAKE_PROFIT
# 199  ClosePositionType.TAKE_PROFIT
# 200    ClosePositionType.STOP_LOSS
# 201    ClosePositionType.STOP_LOSS
# 202    ClosePositionType.STOP_LOSS
# 203  ClosePositionType.TAKE_PROFIT
# 204  ClosePositionType.TAKE_PROFIT
# 205         ClosePositionType.DAYS
# 206  ClosePositionType.TAKE_PROFIT
# 207  ClosePositionType.TAKE_PROFIT
# 208    ClosePositionType.STOP_LOSS
# 209  ClosePositionType.TAKE_PROFIT
# 210    ClosePositionType.STOP_LOSS
# 211  ClosePositionType.TAKE_PROFIT
# 212  ClosePositionType.TAKE_PROFIT
# 213  ClosePositionType.TAKE_PROFIT
# 214  ClosePositionType.TAKE_PROFIT
# 215  ClosePositionType.TAKE_PROFIT
# 216  ClosePositionType.TAKE_PROFIT
# 217  ClosePositionType.TAKE_PROFIT
# 218         ClosePositionType.DAYS
# 219         ClosePositionType.DAYS
# 220  ClosePositionType.TAKE_PROFIT
# 221  ClosePositionType.TAKE_PROFIT
# 222  ClosePositionType.TAKE_PROFIT
# 223    ClosePositionType.STOP_LOSS
# 224  ClosePositionType.TAKE_PROFIT
# 225  ClosePositionType.TAKE_PROFIT
# 226  ClosePositionType.TAKE_PROFIT
# 227    ClosePositionType.STOP_LOSS
# 228    ClosePositionType.STOP_LOSS
# 229    ClosePositionType.STOP_LOSS
# 230  ClosePositionType.TAKE_PROFIT
# 231    ClosePositionType.STOP_LOSS
# 232  ClosePositionType.TAKE_PROFIT
# 233  ClosePositionType.TAKE_PROFIT
# 234         ClosePositionType.DAYS
# 235         ClosePositionType.DAYS
# 236    ClosePositionType.STOP_LOSS
# 237    ClosePositionType.STOP_LOSS
# 238    ClosePositionType.STOP_LOSS
# 239         ClosePositionType.DAYS
# 240  ClosePositionType.TAKE_PROFIT
# 241    ClosePositionType.STOP_LOSS
# 242    ClosePositionType.STOP_LOSS
# 243  ClosePositionType.TAKE_PROFIT
# 244    ClosePositionType.STOP_LOSS
# 245  ClosePositionType.TAKE_PROFIT
# 246    ClosePositionType.STOP_LOSS
# 247         ClosePositionType.DAYS
# 248  ClosePositionType.TAKE_PROFIT
# 249         ClosePositionType.DAYS
# 250  ClosePositionType.TAKE_PROFIT
# 251  ClosePositionType.TAKE_PROFIT
# 252         ClosePositionType.DAYS
# 253  ClosePositionType.TAKE_PROFIT
# 254  ClosePositionType.TAKE_PROFIT
# 255  ClosePositionType.TAKE_PROFIT
# 256  ClosePositionType.TAKE_PROFIT
# 257  ClosePositionType.TAKE_PROFIT
# 258  ClosePositionType.TAKE_PROFIT
# 259  ClosePositionType.TAKE_PROFIT
# 260  ClosePositionType.TAKE_PROFIT
# 261    ClosePositionType.STOP_LOSS
# 262         ClosePositionType.DAYS
# 263  ClosePositionType.TAKE_PROFIT
# 264    ClosePositionType.STOP_LOSS
# 265         ClosePositionType.DAYS
# 266    ClosePositionType.STOP_LOSS
# 267  ClosePositionType.TAKE_PROFIT
# 268  ClosePositionType.TAKE_PROFIT
# 269  ClosePositionType.TAKE_PROFIT
# 270  ClosePositionType.TAKE_PROFIT
# 271  ClosePositionType.TAKE_PROFIT
# 272  ClosePositionType.TAKE_PROFIT
# 273    ClosePositionType.STOP_LOSS
# 274  ClosePositionType.TAKE_PROFIT
# 275         ClosePositionType.DAYS
# 276  ClosePositionType.TAKE_PROFIT
# 277  ClosePositionType.TAKE_PROFIT
# 278  ClosePositionType.TAKE_PROFIT
# 279         ClosePositionType.DAYS
# 280    ClosePositionType.STOP_LOSS
# 281  ClosePositionType.TAKE_PROFIT
# 282    ClosePositionType.STOP_LOSS
# 283    ClosePositionType.STOP_LOSS
# 284    ClosePositionType.STOP_LOSS
# 285    ClosePositionType.STOP_LOSS
# 286         ClosePositionType.DAYS
# 287    ClosePositionType.STOP_LOSS
# 288  ClosePositionType.TAKE_PROFIT
# 289  ClosePositionType.TAKE_PROFIT
# 290    ClosePositionType.STOP_LOSS
# 291  ClosePositionType.TAKE_PROFIT
# 292  ClosePositionType.TAKE_PROFIT
# 293  ClosePositionType.TAKE_PROFIT
# 294  ClosePositionType.TAKE_PROFIT
# 295    ClosePositionType.STOP_LOSS
# 296  ClosePositionType.TAKE_PROFIT
# 297    ClosePositionType.STOP_LOSS
# 298    ClosePositionType.STOP_LOSS
# 299  ClosePositionType.TAKE_PROFIT
# 300  ClosePositionType.TAKE_PROFIT
# 301  ClosePositionType.TAKE_PROFIT
# 302  ClosePositionType.TAKE_PROFIT
# 303  ClosePositionType.TAKE_PROFIT
# 304  ClosePositionType.TAKE_PROFIT
# 305  ClosePositionType.TAKE_PROFIT
# 306    ClosePositionType.STOP_LOSS
# 307    ClosePositionType.STOP_LOSS
# 308    ClosePositionType.STOP_LOSS
# 309         ClosePositionType.DAYS
# 310  ClosePositionType.TAKE_PROFIT
# 311    ClosePositionType.STOP_LOSS
# 312  ClosePositionType.TAKE_PROFIT
# 313         ClosePositionType.DAYS
# 314    ClosePositionType.STOP_LOSS
# 315    ClosePositionType.STOP_LOSS
# 316  ClosePositionType.TAKE_PROFIT
# 317  ClosePositionType.TAKE_PROFIT
# 318  ClosePositionType.TAKE_PROFIT
# 319  ClosePositionType.TAKE_PROFIT
# 320         ClosePositionType.DAYS
# 321    ClosePositionType.STOP_LOSS
# 322  ClosePositionType.TAKE_PROFIT
# 323         ClosePositionType.DAYS
# 324         ClosePositionType.DAYS
# 325         ClosePositionType.DAYS
# 326         ClosePositionType.DAYS
# 327  ClosePositionType.TAKE_PROFIT
# 328  ClosePositionType.TAKE_PROFIT
# 329         ClosePositionType.DAYS
# 330  ClosePositionType.TAKE_PROFIT
# 331         ClosePositionType.DAYS
# 332  ClosePositionType.TAKE_PROFIT
# 333    ClosePositionType.STOP_LOSS
# 334  ClosePositionType.TAKE_PROFIT
# 335  ClosePositionType.TAKE_PROFIT
# 336  ClosePositionType.TAKE_PROFIT
# 337    ClosePositionType.STOP_LOSS
# 338    ClosePositionType.STOP_LOSS
# 339    ClosePositionType.STOP_LOSS
# 340    ClosePositionType.STOP_LOSS
# 341  ClosePositionType.TAKE_PROFIT
# 342    ClosePositionType.STOP_LOSS
# 343  ClosePositionType.TAKE_PROFIT
# 344    ClosePositionType.STOP_LOSS
# 345  ClosePositionType.TAKE_PROFIT
# 346         ClosePositionType.DAYS
# 347  ClosePositionType.TAKE_PROFIT
# 348         ClosePositionType.DAYS
# 349  ClosePositionType.TAKE_PROFIT
# 350         ClosePositionType.DAYS
# 351    ClosePositionType.STOP_LOSS
# 352  ClosePositionType.TAKE_PROFIT
# 353  ClosePositionType.TAKE_PROFIT
# 354    ClosePositionType.STOP_LOSS
# 355         ClosePositionType.DAYS
# 356  ClosePositionType.TAKE_PROFIT
# 357         ClosePositionType.DAYS
# 358         ClosePositionType.DAYS
# 359         ClosePositionType.DAYS
# 360  ClosePositionType.TAKE_PROFIT
# 361  ClosePositionType.TAKE_PROFIT
# 362    ClosePositionType.STOP_LOSS
# 363    ClosePositionType.STOP_LOSS
# 364  ClosePositionType.TAKE_PROFIT
# 365    ClosePositionType.STOP_LOSS
# 366    ClosePositionType.STOP_LOSS
# 367    ClosePositionType.STOP_LOSS
# 368    ClosePositionType.STOP_LOSS
# 369    ClosePositionType.STOP_LOSS
# 370    ClosePositionType.STOP_LOSS
# 371    ClosePositionType.STOP_LOSS
# 372    ClosePositionType.STOP_LOSS
# 373  ClosePositionType.TAKE_PROFIT
# 374         ClosePositionType.DAYS
# 375    ClosePositionType.STOP_LOSS
# 376  ClosePositionType.TAKE_PROFIT
# 377         ClosePositionType.DAYS
# 378  ClosePositionType.TAKE_PROFIT
# 379  ClosePositionType.TAKE_PROFIT
# 380  ClosePositionType.TAKE_PROFIT
# 381  ClosePositionType.TAKE_PROFIT
# 382    ClosePositionType.STOP_LOSS
# 383    ClosePositionType.STOP_LOSS
# 384  ClosePositionType.TAKE_PROFIT
# 385  ClosePositionType.TAKE_PROFIT
# 386  ClosePositionType.TAKE_PROFIT
# 387  ClosePositionType.TAKE_PROFIT
# 388  ClosePositionType.TAKE_PROFIT
# 389    ClosePositionType.STOP_LOSS
# 390  ClosePositionType.TAKE_PROFIT
# 391  ClosePositionType.TAKE_PROFIT
# 392    ClosePositionType.STOP_LOSS
# 393  ClosePositionType.TAKE_PROFIT
# 394    ClosePositionType.STOP_LOSS
# 395  ClosePositionType.TAKE_PROFIT
# 396  ClosePositionType.TAKE_PROFIT
# 397  ClosePositionType.TAKE_PROFIT
# 398  ClosePositionType.TAKE_PROFIT
# 399    ClosePositionType.STOP_LOSS
# 400    ClosePositionType.STOP_LOSS
# 401    ClosePositionType.STOP_LOSS
# 402    ClosePositionType.STOP_LOSS
# 403  ClosePositionType.TAKE_PROFIT
# 404    ClosePositionType.STOP_LOSS
# 405    ClosePositionType.STOP_LOSS
# 406  ClosePositionType.TAKE_PROFIT
# 407         ClosePositionType.DAYS
# 408  ClosePositionType.TAKE_PROFIT
# 409  ClosePositionType.TAKE_PROFIT
# 410    ClosePositionType.STOP_LOSS
# 411    ClosePositionType.STOP_LOSS
# 412  ClosePositionType.TAKE_PROFIT
# 413  ClosePositionType.TAKE_PROFIT
# 414         ClosePositionType.DAYS
# 415         ClosePositionType.DAYS
# 416    ClosePositionType.STOP_LOSS
# 417    ClosePositionType.STOP_LOSS
# 418  ClosePositionType.TAKE_PROFIT
# 419  ClosePositionType.TAKE_PROFIT
# 420    ClosePositionType.STOP_LOSS
# 421         ClosePositionType.DAYS
# 422         ClosePositionType.DAYS
# 423    ClosePositionType.STOP_LOSS
# 424    ClosePositionType.STOP_LOSS
# 425  ClosePositionType.TAKE_PROFIT
# 426  ClosePositionType.TAKE_PROFIT
# 427  ClosePositionType.TAKE_PROFIT
# 428         ClosePositionType.DAYS
# 429  ClosePositionType.TAKE_PROFIT
# 430  ClosePositionType.TAKE_PROFIT
# 431  ClosePositionType.TAKE_PROFIT
# 432  ClosePositionType.TAKE_PROFIT
# 433    ClosePositionType.STOP_LOSS
# 434  ClosePositionType.TAKE_PROFIT
# 435    ClosePositionType.STOP_LOSS
# 436  ClosePositionType.TAKE_PROFIT
# 437  ClosePositionType.TAKE_PROFIT
# 438  ClosePositionType.TAKE_PROFIT
# 439  ClosePositionType.TAKE_PROFIT
# 440    ClosePositionType.STOP_LOSS
# 441    ClosePositionType.STOP_LOSS
# 442  ClosePositionType.TAKE_PROFIT
# 443    ClosePositionType.STOP_LOSS
# 444    ClosePositionType.STOP_LOSS
# 445    ClosePositionType.STOP_LOSS
# 446    ClosePositionType.STOP_LOSS
# 447    ClosePositionType.STOP_LOSS
# 448    ClosePositionType.STOP_LOSS
# 449    ClosePositionType.STOP_LOSS
# 450    ClosePositionType.STOP_LOSS
# 451    ClosePositionType.STOP_LOSS
# 452  ClosePositionType.TAKE_PROFIT
# 453    ClosePositionType.STOP_LOSS
# 454    ClosePositionType.STOP_LOSS
# 455  ClosePositionType.TAKE_PROFIT
# 456  ClosePositionType.TAKE_PROFIT
# 457  ClosePositionType.TAKE_PROFIT
# 458  ClosePositionType.TAKE_PROFIT
# 459         ClosePositionType.DAYS
# 460  ClosePositionType.TAKE_PROFIT
# 461  ClosePositionType.TAKE_PROFIT
# 462  ClosePositionType.TAKE_PROFIT
# 463  ClosePositionType.TAKE_PROFIT
# 464    ClosePositionType.STOP_LOSS
# 465  ClosePositionType.TAKE_PROFIT
# 466  ClosePositionType.TAKE_PROFIT
# 467    ClosePositionType.STOP_LOSS
# 468  ClosePositionType.TAKE_PROFIT
# 469  ClosePositionType.TAKE_PROFIT
# 470    ClosePositionType.STOP_LOSS
# 471  ClosePositionType.TAKE_PROFIT
# 472    ClosePositionType.STOP_LOSS
# 473  ClosePositionType.TAKE_PROFIT
# 474  ClosePositionType.TAKE_PROFIT
# 475  ClosePositionType.TAKE_PROFIT
# 476  ClosePositionType.TAKE_PROFIT
# 477  ClosePositionType.TAKE_PROFIT
# 478    ClosePositionType.STOP_LOSS
# 479  ClosePositionType.TAKE_PROFIT
# 480    ClosePositionType.STOP_LOSS
# 481  ClosePositionType.TAKE_PROFIT
# 482    ClosePositionType.STOP_LOSS
# 483  ClosePositionType.TAKE_PROFIT
# 484  ClosePositionType.TAKE_PROFIT
# 485  ClosePositionType.TAKE_PROFIT
# 486  ClosePositionType.TAKE_PROFIT
# 487  ClosePositionType.TAKE_PROFIT
# 488  ClosePositionType.TAKE_PROFIT
# 489    ClosePositionType.STOP_LOSS
# 490  ClosePositionType.TAKE_PROFIT
# 491  ClosePositionType.TAKE_PROFIT
# 492  ClosePositionType.TAKE_PROFIT
# 493  ClosePositionType.TAKE_PROFIT
# 494  ClosePositionType.TAKE_PROFIT
# 495  ClosePositionType.TAKE_PROFIT
# 496  ClosePositionType.TAKE_PROFIT
# 497  ClosePositionType.TAKE_PROFIT
# 498  ClosePositionType.TAKE_PROFIT
# 499    ClosePositionType.STOP_LOSS
# 500  ClosePositionType.TAKE_PROFIT
# 501  ClosePositionType.TAKE_PROFIT
# 502  ClosePositionType.TAKE_PROFIT
# 503    ClosePositionType.STOP_LOSS
# 504    ClosePositionType.STOP_LOSS
# 505    ClosePositionType.STOP_LOSS
# 506  ClosePositionType.TAKE_PROFIT
# 507    ClosePositionType.STOP_LOSS
# 508  ClosePositionType.TAKE_PROFIT
# 509  ClosePositionType.TAKE_PROFIT
# 510  ClosePositionType.TAKE_PROFIT
# 511  ClosePositionType.TAKE_PROFIT
# 512  ClosePositionType.TAKE_PROFIT
# 513         ClosePositionType.DAYS
# 514  ClosePositionType.TAKE_PROFIT
# 515  ClosePositionType.TAKE_PROFIT
# 516    ClosePositionType.STOP_LOSS
# 517  ClosePositionType.TAKE_PROFIT
# 518    ClosePositionType.STOP_LOSS
# 519  ClosePositionType.TAKE_PROFIT

# %%
orders = orders.sort_values(by='close_time')

# %% [markdown]
# # Cantidad de compras y ventas

# %%
orders.operation_type.value_counts()
# Out:
# operation_type
# OperationType.SELL    286
# OperationType.BUY     234
# Name: count, dtype: int64

# %% [markdown]
# # Compras que salieron bien

# %%
orders[(orders['operation_type']=='OperationType.BUY') & (orders['profit']>0)].shape[0] / orders[(orders['operation_type']=='OperationType.BUY')].shape[0]
# Out:
# 0.6538461538461539

# %% [markdown]
# # Ventas que salieron bien

# %%
orders[(orders['operation_type']=='OperationType.SELL') & (orders['profit']>0)].shape[0] / orders[(orders['operation_type']=='OperationType.SELL')].shape[0]
# Out:
# 0.6713286713286714

# %% [markdown]
# # Cierres por SL y TP

# %%
orders.comment.value_counts()
# Out:
# comment
# ClosePositionType.TAKE_PROFIT    263
# ClosePositionType.STOP_LOSS      163
# ClosePositionType.DAYS            94
# Name: count, dtype: int64

# %%
# orders[(orders['comment']=='ClosePositionType.DAYS') & (orders['profit']>=0)].shape[0] / orders[(orders['comment']=='ClosePositionType.DAYS')].shape[0]

# %% [markdown]
# # Cierres por SL que terminaron positivos

# %%
print(orders[(orders['comment']=='ClosePositionType.STOP_LOSS') & (orders['profit']>=0)].shape[0])
orders[(orders['comment']=='ClosePositionType.STOP_LOSS') & (orders['profit']>=0)].shape[0] / orders[(orders['comment']=='ClosePositionType.STOP_LOSS')].shape[0]
# Out:
# 0
# 0.0

# %% [markdown]
# # Cierres por SL en que se minimizaron las perdidas

# %%
print(orders[(orders['comment']=='ClosePositionType.STOP_LOSS') & (orders['last_price']!=orders['open_price'])].shape[0])
orders[(orders['comment']=='ClosePositionType.STOP_LOSS') & (orders['last_price']!=orders['open_price'])].shape[0] / orders[(orders['comment']=='ClosePositionType.STOP_LOSS')].shape[0]
# Out:
# 0
# 0.0

# %% [markdown]
# # Desempenio por ticker

# %%
orders_by_ticker = orders.groupby('ticker').agg(
    positivas=('profit', lambda x: (x > 0).sum()),
    negativas=('profit', lambda x: (x < 0).sum()),
    profit=('profit', lambda x: (x).sum()),
).reset_index()

orders_by_ticker['perc'] = (orders_by_ticker['positivas'] / (orders_by_ticker['positivas'] + orders_by_ticker['negativas'])) * 100
orders_by_ticker.sort_values(by='perc', ascending=False)
# Out:
#    ticker  positivas  negativas     profit    perc
# 4  USDCHF         47         11 13979.0169 81.0345
# 1  EURUSD         48         16 14914.2558 75.0000
# 3  USDCAD         76         34 20192.2370 69.0909
# 0  AUDUSD         69         32 18081.9991 68.3168
# 5  USDJPY         60         43 13517.6620 58.2524
# 2  GBPUSD         45         39  4858.1078 53.5714

# %% [markdown]
# # Rendimiento por mes

# %%
orders_per_month = orders[['close_time','profit', 'comment']].copy()
orders_per_month['close_time'] = pd.to_datetime(orders_per_month['close_time'])
orders_per_month['year'] = orders_per_month['close_time'].dt.year
orders_per_month['month'] = orders_per_month['close_time'].dt.month
orders_per_month['day'] = orders_per_month['close_time'].dt.day


orders_per_month_gb = orders_per_month.groupby(by=['year','month']).agg(
    amount_ops=('profit', 'count'),
    good_ops=('profit', lambda x: (x > 0).sum()),
    bad_ops=('profit', lambda x: (x < 0).sum()),
    take_profit=('comment', lambda x: (x == 'ClosePositionType.TAKE_PROFIT').sum()),
    stop_loss=('comment', lambda x: (x == 'ClosePositionType.STOP_LOSS').sum()),
    profit_sum=('profit', 'sum'),
    max_profit=('profit', 'max'),

).reset_index()

orders_per_month_gb = pd.concat([
    pd.DataFrame({'year':[2023], 'month':[0],'amount_ops':[0], 'profit_sum':[initial_wallet_value]}), 
    orders_per_month_gb
])

orders_per_month_gb['profit_cumsum'] = orders_per_month_gb['profit_sum'].cumsum()

orders_per_month_gb['perc_change'] = ((orders_per_month_gb['profit_cumsum'] - orders_per_month_gb['profit_cumsum'].shift(1)) / orders_per_month_gb['profit_cumsum'].shift(1))

orders_per_month_gb['perc_change'] = orders_per_month_gb['perc_change'].round(3)

orders_per_month_gb['perc_good_ops'] = (orders_per_month_gb['good_ops'] / orders_per_month_gb['amount_ops'])

orders_per_month_gb[[
    'year', 
    'month', 
    'amount_ops', 
    'take_profit',
    'stop_loss',
    'good_ops', 
    'bad_ops',
    'perc_good_ops',
    'max_profit', 
    'profit_sum', 
    'profit_cumsum', 
    'perc_change', 
]].round(3)
# Out:
#     year  month  amount_ops  take_profit  stop_loss  good_ops  bad_ops  \
# 0   2023      0           0          NaN        NaN       NaN      NaN
# 0   2022      1          42      14.0000    11.0000   27.0000  15.0000
# 1   2022      2          45      19.0000    11.0000   32.0000  13.0000
# 2   2022      3          33      15.0000    11.0000   22.0000  11.0000
# 3   2022      4          36      19.0000     9.0000   27.0000   9.0000
# 4   2022      5          52      26.0000    18.0000   34.0000  18.0000
# 5   2022      6          47      25.0000    14.0000   32.0000  15.0000
# 6   2022      7          45      26.0000    14.0000   30.0000  15.0000
# 7   2022      8          55      27.0000    16.0000   37.0000  18.0000
# 8   2022      9          34      15.0000    13.0000   20.0000  14.0000
# 9   2022     10          39      18.0000    16.0000   22.0000  17.0000
# 10  2022     11          50      29.0000    19.0000   31.0000  19.0000
# 11  2022     12          42      30.0000    11.0000   31.0000  11.0000
#
#     perc_good_ops  max_profit  profit_sum  profit_cumsum  perc_change
# 0             NaN         NaN   1000.0000      1000.0000          NaN
# 0          0.6430     28.9010    342.7600      1342.7600       0.3430
# 1          0.7110     53.6260    716.5070      2059.2670       0.5340
# 2          0.6670     60.0760    625.4600      2684.7270       0.3040
# 3          0.7500     98.7140   1235.0730      3919.8010       0.4600
# 4          0.6540    116.0280   2055.7740      5975.5740       0.5240
# 5          0.6810    177.5600   2963.1910      8938.7650       0.4960
# 6          0.6670    482.6090   5067.9980     14006.7630       0.5670
# 7          0.6730    585.8010   8581.1270     22587.8900       0.6130
# 8          0.5880    556.8000   5803.2860     28391.1760       0.2570
# 9          0.5640    678.0500   6647.5580     35038.7340       0.2340
# 10         0.6200   1039.2000  17960.0890     52998.8230       0.5130
# 11         0.7380   1696.9260  33544.4560     86543.2790       0.6330

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(12, 5))

# Datos de ejemplo
x_wallet = pd.to_datetime(wallet['date'])
y_wallet = wallet['wallet']  # Datos para la línea
# Crear una figura y ejes
# Agregar la línea
ax.plot(x_wallet, y_wallet, label='real_wallet', color='blue')

# Etiquetas de los ejes y leyenda
ax.set_xlabel('Fechas')
ax.set_ylabel('Precios')
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
orders_per_month_gb.perc_change.mean()
# Out:
# 0.45649999999999996

# %%
orders_per_month_gb.perc_change.std()
# Out:
# 0.1377174313915668

# %%
change_percent = orders_per_month_gb.perc_change.reset_index().copy().drop(columns='index')
change_percent.fillna(0, inplace=True)

# Inicializar el valor de partida
initial_value = 3000

# Crear una columna para la suma acumulada
change_percent['cumulative_sum'] = initial_value

# Calcular la suma acumulada basada en los porcentajes
for i in range(1, len(change_percent)):
    change_percent.loc[i, 'cumulative_sum'] = change_percent.loc[i-1, 'cumulative_sum'] * (1 + change_percent.loc[i, 'perc_change'])

change_percent
# Out:
#     perc_change  cumulative_sum
# 0        0.0000       3000.0000
# 1        0.3430       4029.0000
# 2        0.5340       6180.4860
# 3        0.3040       8059.3537
# 4        0.4600      11766.6565
# 5        0.5240      17932.3845
# 6        0.4960      26826.8471
# 7        0.5670      42037.6695
# 8        0.6130      67806.7609
# 9        0.2570      85233.0984
# 10       0.2340     105177.6434
# 11       0.5130     159133.7745
# 12       0.6330     259865.4538

# %% [markdown]
# # Rendimiento por dia

# %%
orders_per_month_gb = orders_per_month.groupby(by=['year','month', 'day']).agg(
    amount_ops=('profit', 'count'),
    good_ops=('profit', lambda x: (x > 0).sum()),
    bad_ops=('profit', lambda x: (x < 0).sum()),
    take_profit=('comment', lambda x: (x == 'ClosePositionType.TAKE_PROFIT').sum()),
    stop_loss=('comment', lambda x: (x == 'ClosePositionType.STOP_LOSS').sum()),
    profit_sum=('profit', 'sum'),
    max_profit=('profit', 'max'),

).reset_index()

orders_per_month_gb = pd.concat([
    pd.DataFrame({'year':[2023], 'month':[0], 'day':[0], 'amount_ops':[0], 'profit_sum':[initial_wallet_value]}), 
    orders_per_month_gb
])

orders_per_month_gb['profit_cumsum'] = orders_per_month_gb['profit_sum'].cumsum()

orders_per_month_gb['perc_change'] = ((orders_per_month_gb['profit_cumsum'] - orders_per_month_gb['profit_cumsum'].shift(1)) / orders_per_month_gb['profit_cumsum'])

orders_per_month_gb['perc_change'] = orders_per_month_gb['perc_change'].round(3)

orders_per_month_gb['perc_good_ops'] = (orders_per_month_gb['good_ops'] / orders_per_month_gb['amount_ops']) * 100

orders_per_month_gb = orders_per_month_gb[[
    'year', 
    'month', 
    'amount_ops', 
    'take_profit',
    'stop_loss',
    'good_ops', 
    'bad_ops',
    'perc_good_ops',
    'max_profit', 
    'profit_sum', 
    'profit_cumsum', 
    'perc_change', 
]].round(3)

orders_per_month_gb[orders_per_month_gb['month']==1]
# Out:
#     year  month  amount_ops  take_profit  stop_loss  good_ops  bad_ops  \
# 0   2022      1           1       1.0000     0.0000    1.0000   0.0000
# 1   2022      1           4       2.0000     2.0000    2.0000   2.0000
# 2   2022      1           2       1.0000     0.0000    2.0000   0.0000
# 3   2022      1           3       2.0000     1.0000    2.0000   1.0000
# 4   2022      1           5       1.0000     1.0000    3.0000   2.0000
# 5   2022      1           2       1.0000     0.0000    2.0000   0.0000
# 6   2022      1           4       1.0000     1.0000    3.0000   1.0000
# 7   2022      1           1       1.0000     0.0000    1.0000   0.0000
# 8   2022      1           2       0.0000     0.0000    2.0000   0.0000
# 9   2022      1           1       0.0000     0.0000    1.0000   0.0000
# 10  2022      1           3       0.0000     1.0000    2.0000   1.0000
# 11  2022      1           1       1.0000     0.0000    1.0000   0.0000
# 12  2022      1           2       0.0000     1.0000    1.0000   1.0000
# 13  2022      1           3       1.0000     1.0000    1.0000   2.0000
# 14  2022      1           3       0.0000     1.0000    1.0000   2.0000
# 15  2022      1           2       0.0000     2.0000    0.0000   2.0000
# 16  2022      1           3       2.0000     0.0000    2.0000   1.0000
#
#     perc_good_ops  max_profit  profit_sum  profit_cumsum  perc_change
# 0        100.0000     19.9340     19.9340      1019.9340       0.0200
# 1         50.0000     20.9380     19.5750      1039.5090       0.0190
# 2        100.0000     20.7980     38.7460      1078.2550       0.0360
# 3         66.6670     21.7800     32.0560      1110.3120       0.0290
# 4         60.0000     22.7380     34.9390      1145.2500       0.0310
# 5        100.0000     23.1340     45.7340      1190.9840       0.0380
# 6         75.0000     24.2450     37.5040      1228.4880       0.0310
# 7        100.0000     24.4880     24.4880      1252.9760       0.0200
# 8        100.0000     28.9010     53.8770      1306.8530       0.0410
# 9        100.0000      7.5790      7.5790      1314.4330       0.0060
# 10        66.6670     10.3130      6.8830      1321.3150       0.0050
# 11       100.0000     26.3390     26.3390      1347.6540       0.0200
# 12        50.0000     10.6010     -3.2340      1344.4200      -0.0020
# 13        33.3330     26.6200     -1.4340      1342.9860      -0.0010
# 14        33.3330      0.8100    -22.8200      1320.1660      -0.0170
# 15         0.0000    -13.0500    -26.1640      1294.0020      -0.0200
# 16        66.6670     26.2260     48.7580      1342.7600       0.0360

# %%
# ticker = 'EURUSD'
# date_from = datetime(2022,1,1)
# date_to = date_from + timedelta(days=30)

# while date_to < datetime(2024,1,1):
#     date_from_str = date_from.strftime('%Y-%m-%d')
#     date_to_str = date_to.strftime('%Y-%m-%d')

#     historical_prices = pd.read_csv(f'./backbone/data/backtest/symbols/{ticker}.csv')
    
#     historical_prices = historical_prices[
#         (historical_prices['Date']>date_from_str)
#         & (historical_prices['Date']<date_to_str)
#     ]
    
#     plt.figure(figsize=(14, 7))
#     plt.plot(historical_prices['Date'], historical_prices['Close'], label=f'{ticker} Price', color='blue')
    
#     # Añadir las operaciones de compra y venta
#     buy_trades = orders[
#         (orders['operation_type']=='OperationType.BUY') 
#         & (orders['close_time']>date_from_str)
#         & (orders['close_time']<date_to_str)
#         & (orders['ticker']==ticker)
#     ]
#     sell_trades = orders[
#         (orders['operation_type']=='OperationType.SELL') 
#         & (orders['close_time']>date_from_str)
#         & (orders['close_time']<date_to_str)
#         & (orders['ticker']==ticker)
#     ]
    
#     # Graficar las operaciones de compra
#     plt.scatter(buy_trades['open_time'], buy_trades['open_price'], color='green', marker='^', s=100, label='Buy Open')
#     plt.scatter(buy_trades['close_time'], buy_trades['close_price'], color='lime', marker='o', s=100, label='Buy Close')
    
#     # Graficar las operaciones de venta
#     plt.scatter(sell_trades['open_time'], sell_trades['open_price'], color='red', marker='v', s=100, label='Sell Open')
#     plt.scatter(sell_trades['close_time'], sell_trades['close_price'], color='orange', marker='o', s=100, label='Sell Close')
    
#     # Añadir etiquetas y leyenda
#     plt.xlabel('Date')
#     plt.ylabel('Price')
#     plt.title(f'{ticker} Price with Buy/Sell Trades')
#     plt.legend()
    
#     # Mostrar el gráfico
#     plt.show()
    
#     print(date_from_str, date_to_str)
   
#     a = input()
    
#     clear_output(wait=True)

#     date_from += timedelta(days=7)
#     date_to = date_from + timedelta(days=15)

# %%
orders_per_month = orders[['close_time','comment', 'ticker', 'profit']].copy()
orders_per_month['close_time'] = pd.to_datetime(orders_per_month['close_time'])
orders_per_month['year'] = orders_per_month['close_time'].dt.year
orders_per_month['month'] = orders_per_month['close_time'].dt.month
orders_per_month['day'] = orders_per_month['close_time'].dt.day

orders_per_month_gb = orders_per_month.groupby(by=['year','month', 'day']).agg(
    take_profit=('comment', lambda x: (x == 'ClosePositionType.TAKE_PROFIT').sum()),
    stop_loss=('comment', lambda x: (x == 'ClosePositionType.STOP_LOSS').sum()),
    profit=('profit', lambda x: (x).sum()),

)

orders_per_month_gb['tp_cumsum'] = orders_per_month_gb.groupby(by=['year','month'])['take_profit'].cumsum()
orders_per_month_gb['sl_cumsum'] = orders_per_month_gb.groupby(by=['year','month'])['stop_loss'].cumsum()
orders_per_month_gb['profit_cumsum'] = orders_per_month_gb.groupby(by=['year','month'])['profit'].cumsum()
orders_per_month_gb
# Out:
#                 take_profit  stop_loss     profit  tp_cumsum  sl_cumsum  \
# year month day
# 2022 1     3              1          0    19.9343          1          0
#            4              2          2    19.5748          3          2
#            5              1          0    38.7462          4          2
#            6              2          1    32.0562          6          3
#            7              1          1    34.9385          7          4
#            10             1          0    45.7337          8          4
#            11             1          1    37.5044          9          5
#            13             1          0    24.4881         10          5
#            14             0          0    53.8769         10          5
#            18             0          0     7.5794         10          5
#            19             0          1     6.8829         10          6
#            21             1          0    26.3389         11          6
#            24             0          1    -3.2343         11          7
#            25             1          1    -1.4341         12          8
#            26             0          1   -22.8201         12          9
#            28             0          2   -26.1635         12         11
#            31             2          0    48.7579         14         11
#      2     3              1          0    26.4084          1          0
#            4              2          1    40.8991          3          1
#            7              1          0    96.5696          4          1
#            8              2          1    63.6099          6          2
#            9              1          1     3.2165          7          3
#            10             2          0    56.5060          9          3
#            31       8581.1270
#      9     2         445.5533
#            5         884.7235
#            6        1194.5618
#            7        2149.0328
#            8        1663.3174
#            12       1901.0674
#            13        680.6557
#            14        212.1812
#            15       1273.2494
#            16       2133.8398
#            19       3144.3688
#            20       3653.8664
#            22       3391.5164
#            28       4706.0651
#            29       5246.4863
#            30       5803.2863
#      10    3         272.5559
#            4         849.6537
#            5        1122.4705
#            6         835.2038
#            10       1427.5265
#            11       2624.0900
#            12       2919.6018
#            13       2602.3185
#            14       1984.5157
#            17       1990.5908
#            18       2600.2513
#            19       4060.9840
#            20       4055.8736
#            21       5208.9382
#            24       5535.9512
#            25       4624.4508
#            27       5293.5670
#            28       5969.5076
#            31       6647.5578
#      11    1        3130.1573
#            2        3896.9390
#            4        6269.6261
#            8        7090.2853
#            9        6663.2806
#            10       4999.4753
#            14       3414.0697
#            15       3785.7081
#            16       4932.3977
#            17       6536.6492
#            18       7786.5593
#            22       9505.2753
#            25      11747.0279
#            28      13119.5425
#            29      13585.0676
#            30      17960.0891
#      12    2        -526.4542
#            5        2657.9301
#            7        6007.9688
#            8        6578.6819
#            9        8969.4067
#            12      10196.3790
#            13      12711.5430
#            15      16706.8290
#            16      18100.9290
#            19      18792.7920
#            20      21688.2592
#            21      20919.2028
#            22      26102.9807
#            23      28539.3146
#            27      30153.7710
#            28      30974.2105
#            29      33544.4557

# %% [markdown]
# # Que hubiera pasado si no se operaba con algunos tickers?

# %%
# tickers_permitidos = orders_by_ticker[orders_by_ticker['profit']>0].ticker.unique()
# print(tickers_permitidos)

tickers_permitidos = [
    'EURUSD', 
    'GBPUSD', 
    # 'USDJPY', 
    'USDCAD', 
    'AUDUSD', 
    'USDCHF'
]

orders_min = orders_per_month[orders_per_month['ticker'].isin(tickers_permitidos)].copy().reset_index()

# %% [markdown]
# # Rendimiento por mes

# %%
orders_per_month_gb = orders_min.groupby(by=['year','month', 'day']).agg(
    amount_ops=('profit', 'count'),
    good_ops=('profit', lambda x: (x > 0).sum()),
    bad_ops=('profit', lambda x: (x < 0).sum()),
    take_profit=('comment', lambda x: (x == 'ClosePositionType.TAKE_PROFIT').sum()),
    stop_loss=('comment', lambda x: (x == 'ClosePositionType.STOP_LOSS').sum()),
    profit_sum=('profit', 'sum'),
    max_profit=('profit', 'max'),

).reset_index()

orders_per_month_gb = pd.concat([
    pd.DataFrame({'year':[2023], 'month':[0], 'day':[0], 'amount_ops':[0], 'profit_sum':[initial_wallet_value]}), 
    orders_per_month_gb
])

orders_per_month_gb['profit_cumsum'] = orders_per_month_gb['profit_sum'].cumsum()

orders_per_month_gb['perc_change'] = ((orders_per_month_gb['profit_cumsum'] - orders_per_month_gb['profit_cumsum'].shift(1)) / orders_per_month_gb['profit_cumsum'])

orders_per_month_gb['perc_change'] = orders_per_month_gb['perc_change'].round(3)

orders_per_month_gb['perc_good_ops'] = (orders_per_month_gb['good_ops'] / orders_per_month_gb['amount_ops']) * 100

orders_per_month_gb = orders_per_month_gb[[
    'year', 
    'month', 
    'amount_ops', 
    'take_profit',
    'stop_loss',
    'good_ops', 
    'bad_ops',
    'perc_good_ops',
    'max_profit', 
    'profit_sum', 
    'profit_cumsum', 
    'perc_change', 
]].round(3)

orders_per_month_gb[orders_per_month_gb['month']==2]
# Out:
#     year  month  amount_ops  take_profit  stop_loss  good_ops  bad_ops  \
# 17  2022      2           1       1.0000     0.0000    1.0000   0.0000
# 18  2022      2           3       2.0000     1.0000    2.0000   1.0000
# 19  2022      2           3       0.0000     0.0000    3.0000   0.0000
# 20  2022      2           3       1.0000     1.0000    2.0000   1.0000
# 21  2022      2           3       1.0000     1.0000    1.0000   2.0000
# 22  2022      2           3       2.0000     0.0000    2.0000   1.0000
# 23  2022      2           2       1.0000     0.0000    2.0000   0.0000
# 24  2022      2           1       0.0000     0.0000    1.0000   0.0000
# 25  2022      2           2       2.0000     0.0000    2.0000   0.0000
# 26  2022      2           1       0.0000     1.0000    0.0000   1.0000
# 27  2022      2           3       0.0000     1.0000    2.0000   1.0000
# 28  2022      2           2       2.0000     0.0000    2.0000   0.0000
# 29  2022      2           3       1.0000     1.0000    2.0000   1.0000
# 30  2022      2           4       1.0000     3.0000    1.0000   3.0000
# 31  2022      2           3       1.0000     1.0000    2.0000   1.0000
#
#     perc_good_ops  max_profit  profit_sum  profit_cumsum  perc_change
# 17       100.0000     26.4080     26.4080      1366.8130       0.0190
# 18        66.6670     27.4750     40.8990      1407.7120       0.0290
# 19       100.0000     25.1920     67.7700      1475.4810       0.0460
# 20        66.6670     30.7960     33.6100      1509.0910       0.0220
# 21        33.3330     30.8520      3.2160      1512.3080       0.0020
# 22        66.6670     32.3790     56.5060      1568.8140       0.0360
# 23       100.0000     32.6400     59.6760      1628.4890       0.0370
# 24       100.0000     17.0820     17.0820      1645.5710       0.0100
# 25       100.0000     34.9550     69.7940      1715.3650       0.0410
# 26         0.0000    -18.0490    -18.0490      1697.3160      -0.0110
# 27        66.6670     27.6520      9.6010      1706.9180       0.0060
# 28       100.0000     37.7660     74.5400      1781.4580       0.0420
# 29        66.6670     40.1670     59.1590      1840.6170       0.0320
# 30        25.0000     39.9540    -19.3890      1821.2280      -0.0110
# 31        66.6670     53.6260     72.5440      1893.7720       0.0380

# %%
orders_min['wallet'] = orders_min['profit']
orders_min.loc[0, 'wallet'] = initial_wallet_value + orders_min.iloc[0]['profit']
orders_min['wallet'] = orders_min['wallet'].cumsum()

# %%
orders_by_ticker = orders_min.groupby('ticker').agg(
    positivas=('profit', lambda x: (x > 0).sum()),
    negativas=('profit', lambda x: (x < 0).sum()),
    profit=('profit', lambda x: (x).sum()),
).reset_index()

orders_by_ticker['perc'] = orders_by_ticker['positivas'] / (orders_by_ticker['positivas'] + orders_by_ticker['negativas'])
orders_by_ticker.sort_values(by='perc', ascending=False)
# Out:
#    ticker  positivas  negativas     profit   perc
# 4  USDCHF         47         11 13979.0169 0.8103
# 1  EURUSD         48         16 14914.2558 0.7500
# 3  USDCAD         76         34 20192.2370 0.6909
# 0  AUDUSD         69         32 18081.9991 0.6832
# 2  GBPUSD         45         39  4858.1078 0.5357

# %%
orders_min[(orders_min['comment']=='ClosePositionType.STOP_LOSS') & (orders_min['profit']>=0)].shape[0] / orders_min[(orders_min['comment']=='ClosePositionType.STOP_LOSS')].shape[0]
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np


# Datos de ejemplo
x_wallet = pd.to_datetime(orders_min['close_time'])
y_wallet = orders_min['wallet']  # Datos para la línea
# Crear una figura y ejes
fig, ax = plt.subplots(figsize=(20, 10))
# Agregar la línea
ax.plot(x_wallet, y_wallet, label='simulated_wallet', color='red')



# Datos de ejemplo
x_wallet = pd.to_datetime(wallet['date'])
y_wallet = wallet['wallet']  # Datos para la línea
# Crear una figura y ejes
# Agregar la línea
ax.plot(x_wallet, y_wallet, label='real_wallet', color='blue')

# Etiquetas de los ejes y leyenda
ax.set_xlabel('Fechas')
ax.set_ylabel('Precios')
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
true_values = pd.read_csv(os.path.join(root_path, path, 'trainres.csv'))
predictions = pd.read_csv(os.path.join(root_path, path, 'test_res.csv')).dropna()

# %%
from sklearn.metrics import f1_score, make_scorer, precision_score, recall_score, classification_report

precision = precision_score(predictions.y_true, predictions.y_pred, average='weighted')
recall = recall_score(predictions.y_true, predictions.y_pred, average='weighted')
f1 = f1_score(predictions.y_true, predictions.y_pred, average='weighted')

print(precision)
print(recall)
print(f1)
# Out:
# 0.7546454184006339
# 0.39356984478935697
# 0.4703859090304917

# %%
fpr_rf, tpr_rf, _ = roc_curve(predictions['y_true'], predictions['y_pred'])
print(classification_report(predictions['y_true'], predictions['y_pred']))

print("Confusion Matrix")
print(confusion_matrix(predictions['y_true'], predictions['y_pred']))

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rf, tpr_rf, label='RF')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.37      0.51      4698
#          1.0       0.12      0.58      0.20       714
#
#     accuracy                           0.39      5412
#    macro avg       0.49      0.47      0.36      5412
# weighted avg       0.75      0.39      0.47      5412
#
# Confusion Matrix
# [[1717 2981]
#  [ 301  413]]

# %%
predictions
# Out:
#       y_true  y_pred                                              proba
# 0     0.0000  1.0000  36446    0.504027\n7998     0.616865\n50670   ...
# 1     0.0000  1.0000  22223    0.643659\n64895    0.574034\n79119   ...
# 2     0.0000  0.0000  36449    0.596307\n22225    0.557124\n64897   ...
# 3     1.0000  0.0000  22227    0.512688\n8003     0.597092\n50675   ...
# 4     0.0000  0.0000  22228    0.509513\n50676    0.531588\n8004    ...
# ...      ...     ...                                                ...
# 5407  0.0000  1.0000  71079    0.501279\n28407    0.514832\n56855   ...
# 5408  0.0000  1.0000  42634    0.537130\n56858    0.561605\n71082   ...
# 5409  0.0000  0.0000  28413    0.521329\n56861    0.558748\n14189   ...
# 5410  0.0000  1.0000  85311    0.512375\n14191    0.548094\n42639   ...
# 5411  1.0000  0.0000  28437    0.514117\n71109    0.619510\n56885   ...
#
# [5412 rows x 3 columns]

# %%
predictions['binary_pred'] = np.where(
    (predictions['y_pred']==0), 
    1 - predictions['proba'], 
    predictions['proba']
)

predictions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 predictions['binary_pred'] = np.where(
#       2     (predictions['y_pred']==0),
# ----> 3     1 - predictions['proba'],
#       4     predictions['proba']
#       5 )
#       7 predictions
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\ops\array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\ops\array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\ops\array_ops.py:135, in _masked_arith_op(x, y, op)
#     132         mask = np.where(y == 1, False, mask)
#     134     if mask.any():
# --> 135         result[mask] = op(xrav[mask], y)
#     137 np.putmask(result, ~mask, np.nan)
#     138 result = result.reshape(x.shape)  # 2D compat
#
# File c:\users\saidj\onedrive\documentos\projects\forex_ml_bot\forex_ml_bot\mtvenv\lib\site-packages\pandas\core\roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
precision, recall, thresholds = precision_recall_curve(predictions['y_true'], predictions['binary_pred'])
pr_auc = auc(recall, precision)
# Plotear la curva de precisión/recall
plt.figure(figsize=(20, 10))

plt.plot(recall, precision, marker='.', label=f'Random Forest (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

# %%
threshold = 0.499291802702681
preds = np.where(
    (predictions['binary_pred']<=threshold),
    0, 
    1
)

print(classification_report(predictions.y_true, preds))

# %%
threshold = 0.499291802702681
preds = np.where(
    (predictions['binary_pred']<=threshold),
    0, 
    1
)

print(classification_report(predictions.y_true, preds))

# %%
predictions[predictions['proba']>threshold]

# %%
predictions.head(50)

# %%
import numpy as np
from sklearn.metrics import precision_recall_curve

def find_best_threshold_fbeta(y_true, y_proba, beta=0.5):
    precision, recall, thresholds = precision_recall_curve(y_true, y_proba)
    
    # Calcular F-beta scores
    fbeta_scores = (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall)
    
    # Evitar división por cero y resultados nan
    fbeta_scores = np.nan_to_num(fbeta_scores)
    
    # Encontrar el umbral que maximiza el F-beta score
    index = np.argmax(fbeta_scores)
    best_threshold = thresholds[index]
    best_precision = precision[index]
    best_recall = recall[index]
    best_fbeta = np.max(fbeta_scores)
    
    return best_threshold, best_precision, best_recall, best_fbeta

# %%
find_best_threshold_fbeta(predictions['y_true'], predictions['binary_pred'], beta=0.5)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import StackingClassifier

def get_xgboost_feature_importance_from_stacking(pipeline):
    """
    Obtiene la importancia de las características del XGBClassifier dentro de un StackingClassifier.

    Parameters:
    pipeline (Pipeline): Un objeto pipeline de sklearn entrenado que contiene un StackingClassifier.

    Returns:
    dict: Un diccionario donde las claves son los nombres de las características y los valores son su importancia.
    """
    if not isinstance(pipeline, Pipeline):
        raise ValueError("El parámetro debe ser un objeto de tipo Pipeline de sklearn.")

    # Intentar obtener el último estimador del pipeline
    final_estimator = pipeline.named_steps[list(pipeline.named_steps.keys())[-1]]

    # Comprobar si el estimador final es un StackingClassifier
    if not isinstance(final_estimator, StackingClassifier):
        raise ValueError("El estimador final del pipeline no es un StackingClassifier.")
    
    # Obtener el ProbabilityTransformer del stack
    prob_transf = final_estimator.named_estimators_['prob_transf']
    
    # Obtener el modelo XGBClassifier dentro del ProbabilityTransformer
    xgb_model = prob_transf.model
    
    # Comprobar si el XGBClassifier tiene el atributo feature_importances_
    if not hasattr(xgb_model, 'feature_importances_'):
        raise ValueError("El XGBClassifier no tiene el atributo feature_importances_.")

    importances = xgb_model.feature_importances_

    # Obtener los nombres de las características
    first_transformer = pipeline.named_steps[list(pipeline.named_steps.keys())[0]]
    if hasattr(first_transformer, 'get_feature_names_out'):
        feature_names = first_transformer.get_feature_names_out()
    else:
        feature_names = pipeline['preprocessor'].get_feature_names_out()  # Ajustar según el nombre de tu primer paso

    return dict(zip(feature_names, importances))

# %%
pipeline_path = 'C:/Users/SaidJ/OneDrive/Documentos/projects/forex_ml_bot/forex_ml_bot/backbone/data/backtest/experiments/Mode_train-Model_gradient_boosting-TrainWw_5760-TrainPd_24-TradStgy_ml_strategy-PerFwTg_8-SL_10-RR_2-CloseByTimeTrue-TS_True/pipe.pkl'

# %%
import joblib

with open(pipeline_path, 'rb') as file:
    pipeline = joblib.load(file)

features = get_xgboost_feature_importance_from_stacking(pipeline)
features_df = pd.DataFrame({'feature':features.keys(), 'importance':features.values()})
features_df.sort_values(by='importance', ascending=False)

# %%
from sklearn.metrics import precision_score, f1_score, recall_score



tickers = config["tickers"] 
tickers

predictions = predictions.sort_values(by='fecha')
true_values = true_values.sort_values(by='fecha')


# renombro las columnas
column_names = {}
for column in predictions.columns:
    if column != 'fecha':
        column_names[column] = f'{column}_preds'

predictions = predictions.rename(columns=column_names)

column_names = {}
for column in true_values.columns:
    if column != 'fecha':
        column_names[column] = f'{column}_true'

true_values = true_values.rename(columns=column_names)
performance = pd.concat(
    [
        predictions,
        true_values
    ], axis=1, join="inner"
)

recall_list = []
f1_list = []
precision_list = []

for ticker in tickers:
    y_true = performance[performance[f'{ticker}_true'].notna()][f'{ticker}_true']
    y_pred = performance[performance[f'{ticker}_preds'].notna()][f'{ticker}_preds']
    
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    # print(classification_report(performance[f'{ticker}_true'], performance[f'{ticker}_preds'], target_names=target_names))
    
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)

# %% [markdown]
# # Grafico de velas

# %%
# import plotly.graph_objects as go

# fig = go.Figure(data=[go.Candlestick(x=prices['Date'],
#                 open=prices['Open'],
#                 high=prices['High'],
#                 low=prices['Low'],
#                 close=prices['Close'])])

# fig.update_layout(
#     title=f"{config['ticker']}",
#     yaxis_title=f"{config['ticker']} Stock"
# )

# fig.show()

# %% [markdown]
# # Estrategia

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
x_prices = pd.to_datetime(prices['Date'])
y_prices = prices['Close']  # Datos para la línea

x_buy = pd.to_datetime(buys['fecha'])
y_buy = buys['buy']  # Datos para el scatter plot

x_sell = pd.to_datetime(sells['date'])
y_sell = sells['sell']  # Datos para el scatter plot

x_wallet = pd.to_datetime(wallet['date'])
y_wallet = wallet['wallet']  # Datos para la línea

# Crear una figura y ejes
fig, ax = plt.subplots(figsize=(20, 10))

# Agregar la línea
ax.plot(x_prices, y_prices, label='market', color='black')

ax.plot(x_wallet, y_wallet, label='wallet', color='purple')

# Agregar el scatter plot
ax.scatter(x_buy, y_buy, label='compras', color='cyan', marker='>')

ax.scatter(x_sell, y_sell, label='Ventas', color='red', marker='o')

# Etiquetas de los ejes y leyenda
ax.set_xlabel('Fechas')
ax.set_ylabel('Precios')
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
x_prices = pd.to_datetime(prices['Date'])
y_prices = prices['Close']  # Datos para la línea

x_buy = pd.to_datetime(buys['date'])
y_buy = buys['buy']  # Datos para el scatter plot

x_sell = pd.to_datetime(sells['date'])
y_sell = sells['sell']  # Datos para el scatter plot

# Crear una figura y ejes
fig, ax = plt.subplots(figsize=(20, 10))

# Agregar la línea
ax.plot(x_prices, y_prices, label='market', color='black')

# Agregar el scatter plot
ax.scatter(x_buy, y_buy, label='compras', color='cyan', marker='>')

ax.scatter(x_sell, y_sell, label='Ventas', color='red', marker='o')

# Etiquetas de los ejes y leyenda
ax.set_xlabel('Fechas')
ax.set_ylabel('Precios')
ax.legend()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import auc

print('Area bajo la curva: ', auc(wallet.index, wallet['wallet']))

# Datos de ejemplo
x_prices = pd.to_datetime(wallet['date'])
y_prices = wallet['wallet']  # Datos para la línea


# Crear una figura y ejes
fig, ax = plt.subplots(figsize=(20, 10))

# Agregar la línea
ax.plot(x_prices, y_prices, label='Wallet', color='blue')

# Etiquetas de los ejes y leyenda
ax.set_xlabel('Fechas')
ax.set_ylabel('Precios')
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Modelo

# %%
predictions.sort_values(by='fecha')

# %%
true_values.sort_values(by='fecha')

# %%
accuracy_score(predictions[predictions['YPF'].notna()].YPF, true_values[true_values['YPF'].notna()].YPF)

# %%
threshold_down = 0.5
threshold_up = 0.5

df_predictions = performance[(performance['y_pred']<threshold_down) | (performance['y_pred']>threshold_up)].copy()
df_predictions['y_pred'] = np.where(df_predictions['y_pred']<threshold_down, 0, df_predictions['y_pred'])
df_predictions['y_pred'] = np.where(df_predictions['y_pred']>threshold_up, 1, df_predictions['y_pred'])

print(accuracy_score(df_predictions.y_true, df_predictions.y_pred))
plot_confusion_matrix(df_predictions.y_true, df_predictions.y_pred, classes=[0,1], cmap=plt.cm.Reds)

# %%
threshold_down = 0.1
threshold_up = 0.9

df_predictions = performance[(performance['y_pred']<threshold_down) | (performance['y_pred']>threshold_up)].copy()
df_predictions['y_pred'] = np.where(df_predictions['y_pred']<threshold_down, 0, df_predictions['y_pred'])
df_predictions['y_pred'] = np.where(df_predictions['y_pred']>threshold_up, 1, df_predictions['y_pred'])

print(accuracy_score(df_predictions.y_true, df_predictions.y_pred))
plot_confusion_matrix(df_predictions.y_true, df_predictions.y_pred, classes=[0,1], cmap=plt.cm.Reds)

# %%
plt.hist(performance.y_pred, color='lightgreen', ec='black', bins=50)
plt.show()

# %%
buys = buys.rename(columns={''})

# %%
operations = pd.concat([buys[buys['YPF'].notna()], sells[sells['YPF'].notna()]], axis=1, join="inner")[['fecha','YPF']]
operations

# %%
operations['positive'] = np.where(operations['buy']>operations['sell'], 0, 1)
operations['Profit'] = operations['sell'] - operations['buy'] 
operations['positive'].value_counts()
